# %% [markdown]
# # Resultados - Proposta
#
# K-Best 5

# %%
import pandas as pd
import math

from datetime import datetime

current_datetime_gen = datetime.now().strftime("%Y-%m-%d %H:%M")
current_datetime_gen
# Out:
# '2024-08-21 17:24'

# %% [markdown]
# ## Erro para todas as safras

# %%
train_test_results_df = pd.read_csv("Data/proposta_results_k-best_harvest_all.csv")

train_test_results_df.head(40)
# Out:
#     Unnamed: 0  index  planting_relative_day      safra  \
# 0            0      6                    104  2021/2022
# 1            1      8                     56  2021/2022
# 2            2     10                    104  2021/2022
# 3            3     17                     82  2021/2022
# 4            0      4                     82  2021/2022
# 5            1      7                     82  2021/2022
# 6            2     11                    104  2021/2022
# 7            3     16                     82  2021/2022
# 8            0      1                    116  2021/2022
# 9            1      9                    116  2021/2022
# 10           2     12                    104  2021/2022
# 11           3     15                     82  2021/2022
# 12           0      2                    116  2021/2022
# 13           1      3                     82  2021/2022
# 14           2     13                     82  2021/2022
# 15           0      0                    116  2021/2022
# 16           1      5                    104  2021/2022
# 17           2     14                     82  2021/2022
# 18           0      6                     82  2020/2021
# 19           1      9                    104  2020/2021
# 20           2     10                    104  2020/2021
# 21           3     11                     68  2020/2021
# 22           4     13                     82  2020/2021
# 23           5     14                     68  2020/2021
# 24           6     17                     82  2020/2021
# 25           7     18                     82  2020/2021
# 26           8     21                     82  2020/2021
# 27           9     24                     82  2020/2021
# 28          10     25                    116  2020/2021
# 29          11     32                    104  2020/2021
# 30          12     48                     82  2020/2021
# 31          13     61                    104  2020/2021
# 32          14     67                    116  2020/2021
# 33          15     74                    104  2020/2021
# 34          16     76                     82  2020/2021
# 35          17     85                     82  2020/2021
# 36          18     91                     68  2020/2021
# 37          19     94                     68  2020/2021
# 38           0      1                     82  2020/2021
# 39           1      5                    116  2020/2021
#
#     predicted_planting_relative_day  distance  fold
# 0                            102.06      1.94     1
# 1                             94.00     38.00     1
# 2                            100.42      3.58     1
# 3                             95.34     13.34     1
# 4                             69.38     12.62     2
# 5                            111.72     29.72     2
# 6                            103.00      1.00     2
# 7                             92.12     10.12     2
# 8                             86.48     29.52     3
# 9                            100.40     15.60     3
# 10                            80.32     23.68     3
# 11                            79.06      2.94     3
# 12                            94.36     21.64     4
# 13                           104.28     22.28     4
# 14                            86.86      4.86     4
# 15                            86.08     29.92     5
# 16                           110.66      6.66     5
# 17                            87.48      5.48     5
# 18                            79.90      2.10     1
# 19                            83.78     20.22     1
# 20                            82.44     21.56     1
# 21                            78.02     10.02     1
# 22                            82.14      0.14     1
# 23                            78.02     10.02     1
# 24                            86.48      4.48     1
# 25                            88.12      6.12     1
# 26                            81.10      0.90     1
# 27                            82.88      0.88     1
# 28                           102.00     14.00     1
# 29                            86.26     17.74     1
# 30                            82.00      0.00     1
# 31                            88.18     15.82     1
# 32                           101.60     14.40     1
# 33                           102.00      2.00     1
# 34                            80.84      1.16     1
# 35                            83.84      1.84     1
# 36                            91.30     23.30     1
# 37                            93.56     25.56     1
# 38                            80.32      1.68     2
# 39                            83.98     32.02     2

# %%
train_test_results_df["planting_relative_day"].plot(kind="hist", xlim=(0, 300), ylim=(0, 3000), title=f"Distribuição de 'dia relativo da safra' ocorrido (ML) >{current_datetime_gen}<")
# Out:
# <Axes: title={'center': "Distribuição de 'dia relativo da safra' ocorrido (ML) >2024-08-21 17:24<"}, ylabel='Frequency'>

# %%
train_test_results_df["predicted_planting_relative_day"].plot(kind="hist", xlim=(0, 300), ylim=(0, 3000), title=f"Distribuição de 'dia relativo da safra' predito (ML) >{current_datetime_gen}<")
# Out:
# <Axes: title={'center': "Distribuição de 'dia relativo da safra' predito (ML) >2024-08-21 17:24<"}, ylabel='Frequency'>

# %%
K_FOLDS = 5

each_fold_error_list = []


for k_num in range(1, K_FOLDS + 1):
    df = train_test_results_df.copy()
    df = df[df["fold"] == k_num]
    
    df['distance_pow2'] = pow(df['predicted_planting_relative_day'] - df['planting_relative_day'], 2)
    
    error_rmse = {
        'error': math.sqrt(df['distance_pow2'].sum() / df.shape[0]),
    }

    print(f"=====> Fold: {k_num}")
    print(f"=====> Average error: {error_rmse['error']}")
    print()

    each_fold_error_list.append({
        "fold": k_num,
        "error": error_rmse['error'],
    })

each_fold_error_list
# Out:
# =====> Fold: 1
# =====> Average error: 12.924055113182796
#
# =====> Fold: 2
# =====> Average error: 12.957640750860412
#
# =====> Fold: 3
# =====> Average error: 12.94065170527596
#
# =====> Fold: 4
# =====> Average error: 12.641485077416096
#
# =====> Fold: 5
# =====> Average error: 11.989872520557944
# [{'fold': 1, 'error': 12.924055113182796},
#  {'fold': 2, 'error': 12.957640750860412},
#  {'fold': 3, 'error': 12.94065170527596},
#  {'fold': 4, 'error': 12.641485077416096},
#  {'fold': 5, 'error': 11.989872520557944}]

# %%
each_fold_error_df = pd.DataFrame(each_fold_error_list)

error = each_fold_error_df["error"].mean()
error_df = pd.DataFrame([{
    "safra": "Todas (média)",
    "error": error,
}])

print(f"Erro para todas as safras: {error}")

ax = error_df.plot(x="safra", y="error", kind="bar", ylim=(0, 50), rot=5, fontsize=10, title=f"Proposta: Erro para todas as safras >{current_datetime_gen}<")
ax.bar_label(ax.containers[0])
# Out:
# Erro para todas as safras: 12.690741033458643
# [Text(0, 0, '12.6907')]

# %% [markdown]
# ## Erros para cada safra

# %%
train_test_results_safra_df = pd.read_csv("Data/proposta_results_harvest_all.csv")
safras = train_test_results_safra_df["safra"].unique()

print(safras)
train_test_results_safra_df.head()
# Out:
# ['2021/2022' '2020/2021' '2019/2020' '2018/2019' '2017/2018' '2016/2017'
#  '2015/2016' '2014/2015' '2013/2014' '2012/2013' '2011/2012' '2010/2011'
#  '2009/2010' '2008/2009' '2007/2008' '2006/2007' '2005/2006' '2004/2005']
#    Unnamed: 0  index  planting_relative_day      safra  \
# 0           0      6                    104  2021/2022
# 1           1      8                     56  2021/2022
# 2           2     10                    104  2021/2022
# 3           3     17                     82  2021/2022
# 4           0      4                     82  2021/2022
#
#    predicted_planting_relative_day  distance  fold
# 0                           100.44      3.56     1
# 1                            92.90     36.90     1
# 2                           102.38      1.62     1
# 3                            91.46      9.46     1
# 4                            74.46      7.54     2

# %%
K_FOLDS = 5

each_safra_fold_error_list = []

for safra in safras:
    for k_num in range(1, K_FOLDS + 1):
        df = train_test_results_safra_df.copy()
        df = df[df["fold"] == k_num]
        df = df[df["safra"] == safra]
        
        # calculating average accuracy for 5d, 10d and 15d
        df['distance_pow2'] = pow(df['predicted_planting_relative_day'] - df['planting_relative_day'], 2)
        
        error_rmse = {
            'error': math.sqrt(df['distance_pow2'].sum() / df.shape[0]),
        }
    
        print(f"=====> Fold: {k_num}")
        print(f"=====> Average error: {error_rmse['error']}")
        print()
    
        each_safra_fold_error_list.append({
            "safra": safra,
            "fold": k_num,
            "error": error_rmse['error'],
        })

each_safra_fold_error_df = pd.DataFrame(each_safra_fold_error_list)
each_safra_fold_error_df
# Out:
# =====> Fold: 1
# =====> Average error: 19.146798688031378
#
# =====> Fold: 2
# =====> Average error: 15.74911108602641
#
# =====> Fold: 3
# =====> Average error: 21.206359895088077
#
# =====> Fold: 4
# =====> Average error: 17.57879025037464
#
# =====> Fold: 5
# =====> Average error: 16.985805838993926
#
# =====> Fold: 1
# =====> Average error: 13.384271366047535
#
# =====> Fold: 2
# =====> Average error: 14.710064581775296
#
# =====> Fold: 3
# =====> Average error: 9.766297148868654
#
# =====> Fold: 4
# =====> Average error: 8.864789901627676
#
# =====> Fold: 5
# =====> Average error: 14.603001746216425
#
# =====> Fold: 1
# =====> Average error: 20.42538877638971
#
# =====> Fold: 2
# =====> Average error: 17.980829473954437
#
# =====> Fold: 3
# =====> Average error: 22.23529305277664
#
# =====> Fold: 4
# =====> Average error: 14.901420833502515
#
# =====> Fold: 5
# =====> Average error: 15.839848484123829
#
# =====> Fold: 1
# =====> Average error: 18.794089496434776
#
# =====> Fold: 2
# =====> Average error: 19.317923456382847
#
# =====> Fold: 3
# =====> Average error: 21.697446854411233
#
# =====> Fold: 4
# =====> Average error: 16.388245233037665
#
# =====> Fold: 5
# =====> Average error: 12.657143150303419
#
# =====> Fold: 1
# =====> Average error: 12.383640681226952
#
# =====> Fold: 2
# =====> Average error: 10.010923598966672
#
# =====> Fold: 3
# =====> Average error: 14.02240009227472
#
# =====> Fold: 4
# =====> Average error: 9.068976087339037
#
# =====> Fold: 5
# =====> Average error: 11.678071914334302
#
# =====> Fold: 1
# =====> Average error: 17.989489914069853
#
# =====> Fold: 2
# =====> Average error: 11.655833021326815
#
# =====> Fold: 3
# =====> Average error: 14.47044383344347
#
# =====> Fold: 4
# =====> Average error: 17.454169193124667
#
# =====> Fold: 5
# =====> Average error: 15.470320865862602
#
# =====> Fold: 1
# =====> Average error: 12.82452976277741
#
# =====> Fold: 2
# =====> Average error: 13.198037559749988
#
# =====> Fold: 3
# =====> Average error: 10.648365130861897
#
# =====> Fold: 4
# =====> Average error: 12.719390469150065
#
# =====> Fold: 5
# =====> Average error: 16.023524166661236
#
# =====> Fold: 1
# =====> Average error: 14.616855567004373
#
# =====> Fold: 2
# =====> Average error: 11.262148009051282
#
# =====> Fold: 3
# =====> Average error: 14.820528555576779
#
# =====> Fold: 4
# =====> Average error: 14.814879157267685
#
# =====> Fold: 5
# =====> Average error: 14.438104812898239
#
# =====> Fold: 1
# =====> Average error: 13.270367848595495
#
# =====> Fold: 2
# =====> Average error: 8.689494039739404
#
# =====> Fold: 3
# =====> Average error: 9.026417886363298
#
# =====> Fold: 4
# =====> Average error: 6.882241882797592
#
# =====> Fold: 5
# =====> Average error: 7.723432657731825
#
# =====> Fold: 1
# =====> Average error: 18.29765022795917
#
# =====> Fold: 2
# =====> Average error: 9.412327801608246
#
# =====> Fold: 3
# =====> Average error: 12.170842810885066
#
# =====> Fold: 4
# =====> Average error: 11.75061615943022
#
# =====> Fold: 5
# =====> Average error: 10.14339014513213
#
# =====> Fold: 1
# =====> Average error: 13.762957530996019
#
# =====> Fold: 2
# =====> Average error: 20.866803780167196
#
# =====> Fold: 3
# =====> Average error: 24.274770853707356
#
# =====> Fold: 4
# =====> Average error: 10.811674245925097
#
# =====> Fold: 5
# =====> Average error: 12.035335475174758
#
# =====> Fold: 1
# =====> Average error: 15.857546538125382
#
# =====> Fold: 2
# =====> Average error: 14.926650940318794
#
# =====> Fold: 3
# =====> Average error: 14.356924733668894
#
# =====> Fold: 4
# =====> Average error: 17.633264323334327
#
# =====> Fold: 5
# =====> Average error: 14.552841824356884
#
# =====> Fold: 1
# =====> Average error: 12.457961917684292
#
# =====> Fold: 2
# =====> Average error: 10.987854121628486
#
# =====> Fold: 3
# =====> Average error: 12.930164449997326
#
# =====> Fold: 4
# =====> Average error: 8.596531510407784
#
# =====> Fold: 5
# =====> Average error: 12.97298892105442
#
# =====> Fold: 1
# =====> Average error: 10.335898732079652
#
# =====> Fold: 2
# =====> Average error: 12.201771133943637
#
# =====> Fold: 3
# =====> Average error: 11.414175389058201
#
# =====> Fold: 4
# =====> Average error: 12.017132055581165
#
# =====> Fold: 5
# =====> Average error: 9.897730176615159
#
# =====> Fold: 1
# =====> Average error: 11.378164843603528
#
# =====> Fold: 2
# =====> Average error: 12.78309217751676
#
# =====> Fold: 3
# =====> Average error: 10.740868211802873
#
# =====> Fold: 4
# =====> Average error: 10.95816145389697
#
# =====> Fold: 5
# =====> Average error: 11.609904812196103
#
# =====> Fold: 1
# =====> Average error: 9.93846168642491
#
# =====> Fold: 2
# =====> Average error: 9.467711316487916
#
# =====> Fold: 3
# =====> Average error: 11.934457592453377
#
# =====> Fold: 4
# =====> Average error: 11.74224727994784
#
# =====> Fold: 5
# =====> Average error: 9.972871972075149
#
# =====> Fold: 1
# =====> Average error: 12.188391399861617
#
# =====> Fold: 2
# =====> Average error: 9.484838530225195
#
# =====> Fold: 3
# =====> Average error: 12.091695631150934
#
# =====> Fold: 4
# =====> Average error: 13.093297187998658
#
# =====> Fold: 5
# =====> Average error: 11.318411174554118
#
# =====> Fold: 1
# =====> Average error: 14.465907400611858
#
# =====> Fold: 2
# =====> Average error: 12.064496546606366
#
# =====> Fold: 3
# =====> Average error: 11.190508835616011
#
# =====> Fold: 4
# =====> Average error: 7.076347080238505
#
# =====> Fold: 5
# =====> Average error: 14.091670163610843
#         safra  fold      error
# 0   2021/2022     1  19.146799
# 1   2021/2022     2  15.749111
# 2   2021/2022     3  21.206360
# 3   2021/2022     4  17.578790
# 4   2021/2022     5  16.985806
# ..        ...   ...        ...
# 85  2004/2005     1  14.465907
# 86  2004/2005     2  12.064497
# 87  2004/2005     3  11.190509
# 88  2004/2005     4   7.076347
# 89  2004/2005     5  14.091670
#
# [90 rows x 3 columns]

# %%
df = each_safra_fold_error_df.copy()
df = df[["safra", "error"]].groupby("safra", as_index=False).mean()

each_safra_fold_error_df = df
each_safra_fold_error_df.head(40)
# Out:
#         safra      error
# 0   2004/2005  11.777786
# 1   2005/2006  11.635327
# 2   2006/2007  10.611150
# 3   2007/2008  11.494038
# 4   2008/2009  11.173341
# 5   2009/2010  11.589100
# 6   2010/2011  15.465446
# 7   2011/2012  16.350308
# 8   2012/2013  12.354965
# 9   2013/2014   9.118391
# 10  2014/2015  13.990503
# 11  2015/2016  13.082769
# 12  2016/2017  15.408051
# 13  2017/2018  11.432802
# 14  2018/2019  17.770970
# 15  2019/2020  18.276556
# 16  2020/2021  12.265685
# 17  2021/2022  18.133373

# %%
each_safra_fold_error_df.plot(x="safra", y="error", ylim=(0, 50), kind="bar", rot=30, fontsize=8, title=f"Proposta: Erros para cada safra >{current_datetime_gen}<")
# Out:
# <Axes: title={'center': 'Proposta: Erros para cada safra >2024-08-21 17:24<'}, xlabel='safra'>
